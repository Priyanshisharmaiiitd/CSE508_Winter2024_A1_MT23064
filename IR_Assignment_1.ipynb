# %% [markdown]
# There are total 999 text files and on each file we have to perform the following operations
# 1)lowercase the text
# 2)perform tokenization
# 3)remove stopword
# 4)remove punctuations
# 5)remove blank space tokens
# we have to save each file after all these operations
# we have to print content of 5 file after each operation.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import shutil
import string

def copy_files(source_folder, destination_folder):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    for filename in os.listdir(source_folder):
        source_file = os.path.join(source_folder, filename)
        destination_file = os.path.join(destination_folder, filename)

        if os.path.isfile(source_file):
            shutil.copy2(source_file, destination_file)
            print(f"File '{filename}' copied successfully.")

source_folder = "/content/drive/MyDrive/IR-A1"
destination_folder = "/content/drive/MyDrive/IR_A1-copy"

copy_files(source_folder, destination_folder)
# Out:
# File 'file607.txt' copied successfully.
# File 'file541.txt' copied successfully.
# File 'file67.txt' copied successfully.
# File 'file717.txt' copied successfully.
# File 'file144.txt' copied successfully.
# File 'file930.txt' copied successfully.
# File 'file281.txt' copied successfully.
# File 'file516.txt' copied successfully.
# File 'file689.txt' copied successfully.
# File 'file532.txt' copied successfully.
# File 'file430.txt' copied successfully.
# File 'file211.txt' copied successfully.
# File 'file400.txt' copied successfully.
# File 'file824.txt' copied successfully.
# File 'file963.txt' copied successfully.
# File 'file310.txt' copied successfully.
# File 'file123.txt' copied successfully.
# File 'file967.txt' copied successfully.
# File 'file48.txt' copied successfully.
# File 'file330.txt' copied successfully.
# File 'file985.txt' copied successfully.
# File 'file514.txt' copied successfully.
# File 'file368.txt' copied successfully.
# ...

# %%
#we will first lowercase the text for each file and print content of first 5 files
import os
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')

folder_path = '/content/drive/MyDrive/IR_A1-copy'
os.chdir(folder_path)

for i, file_name in enumerate(os.listdir(folder_path)):
    if i >= 5 or not file_name.endswith('.txt'):
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} before converting to lowercase:\n{content}\n")

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        with open(file_name, 'r') as file:
            content = file.read().lower()
        with open(file_name, 'w') as file:
            file.write(content)

for i, file_name in enumerate(os.listdir(folder_path)):
    if i >= 5 or not file_name.endswith('.txt'):
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} after converting to lowercase:\n{content}\n")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Content of file607.txt before converting to lowercase:
# Bought a 3 pack. Liked em so much I bought three more.
#
# I wouldnt trust em just anchored it to sheetrock though. Just me! Find some studs. Or buy a 1x6, screw it to the studs then mount the hangers to the 1x6
#
# Content of file541.txt before converting to lowercase:
# ...

# %%
#we will now apply tokenization and print content of sample 5 files before and after tokenization

for i, file_name in enumerate(os.listdir(folder_path)):
    if i >= 5 or not file_name.endswith('.txt'):
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} before tokenization:\n{content}\n")

all_tokens = {}
for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        with open(file_name, 'r') as file:
            content = file.read()
            tokens = word_tokenize(content)
            all_tokens[file_name] = tokens

for i, (file_name, tokens) in enumerate(all_tokens.items()):
    if i >= 5:
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} after tokenization:\n{content}\n")
    print(f"Tokens of {file_name}:\n{tokens}\n")
# Out:
# Content of file607.txt before tokenization:
# bought a 3 pack. liked em so much i bought three more.
#
# i wouldnt trust em just anchored it to sheetrock though. just me! find some studs. or buy a 1x6, screw it to the studs then mount the hangers to the 1x6
#
# Content of file541.txt before tokenization:
# ...

# %%
#now we will remove stopwords from each file and print conetent of 5 sample files before and after removing stopwords
from nltk.corpus import stopwords
import string
nltk.download('stopwords')

for i, file_name in enumerate(os.listdir(folder_path)):
    if i >= 5 or not file_name.endswith('.txt'):
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} before removing stopwords:\n{content}\n")

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        with open(file_name, 'r') as file:
            content = file.read()
        tokens = word_tokenize(content)
        stop_words = set(stopwords.words('english'))
        tokens_without_stopwords = [token for token in tokens if token.lower() not in stop_words]
        processed_content = ' '.join(tokens_without_stopwords)

        with open(file_name, 'w') as file:
            file.write(processed_content)

for i, file_name in enumerate(os.listdir(folder_path)):
    if i >= 5 or not file_name.endswith('.txt'):
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} after removing stopwords:\n{content}\n")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Content of file607.txt before removing stopwords:
# bought a 3 pack. liked em so much i bought three more.
#
# i wouldnt trust em just anchored it to sheetrock though. just me! find some studs. or buy a 1x6, screw it to the studs then mount the hangers to the 1x6
#
# Content of file541.txt before removing stopwords:
# ...

# %%
#remove punctuation
for i, file_name in enumerate(os.listdir(folder_path)):
    if i >= 5 or not file_name.endswith('.txt'):
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} before removing punctuations:\n{content}\n")

processed_contents = {}

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        with open(file_name, 'r') as file:
            content = file.read()
            tokens = word_tokenize(content)
            tokens_without_punctuations = [token for token in tokens if token not in string.punctuation]
            processed_content = ' '.join(tokens_without_punctuations)

            processed_contents[file_name] = processed_content

for file_name, processed_content in processed_contents.items():
    with open(file_name, 'w') as file:
        file.write(processed_content)

for i, file_name in enumerate(os.listdir(folder_path)):
    if i >= 5 or not file_name.endswith('.txt'):
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} after removing punctuations:\n{content}\n")
# Out:
# Content of file607.txt before removing punctuations:
# bought 3 pack liked em much bought three wouldnt trust em anchored sheetrock though find studs buy 1x6 screw studs mount hangers 1x6
#
# Content of file541.txt before removing punctuations:
# many people think electric guitar around 100 bucks cheap sounds terrible guitar makes opinion wrong guitar amazing price first part guitars character notice beautiful red color looks beautiful really eye catching playability nice good action strings comes decent factory strings changed anyway better sound volume tone knobs cool looking also tune matic bridge helps alot kept guitar tune days guitar also comes amp cable papers owners guide poster big epiphone sticker doesnt love stickers lol highly recommend guitar beginners playing sound quality amazing price get
#
# Content of file67.txt before removing punctuations:
# looks great sons fender acustic easy put
#
# Content of file717.txt before removing punctuations:
# ...

# %%
#remove blank spaces
for i, file_name in enumerate(os.listdir(folder_path)):
    if i >= 5 or not file_name.endswith('.txt'):
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} before removing blank spaces:\n{content}\n")


processed_contents = {}

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        with open(file_name, 'r') as file:
            content = file.read()
            processed_content = ' '.join(token.strip() for token in content.split() if token.strip() != '')

            processed_contents[file_name] = processed_content

for file_name, processed_content in processed_contents.items():
    with open(file_name, 'w') as file:
        file.write(processed_content)

for i, file_name in enumerate(os.listdir(folder_path)):
    if i >= 5 or not file_name.endswith('.txt'):
        break
    with open(file_name, 'r') as file:
        content = file.read()
        print(f"Content of {file_name} after removing blank spaces:\n{content}\n")
# Out:
# Content of file607.txt before removing blank spaces:
# bought 3 pack liked em much bought three wouldnt trust em anchored sheetrock though find studs buy 1x6 screw studs mount hangers 1x6
#
# Content of file541.txt before removing blank spaces:
# many people think electric guitar around 100 bucks cheap sounds terrible guitar makes opinion wrong guitar amazing price first part guitars character notice beautiful red color looks beautiful really eye catching playability nice good action strings comes decent factory strings changed anyway better sound volume tone knobs cool looking also tune matic bridge helps alot kept guitar tune days guitar also comes amp cable papers owners guide poster big epiphone sticker doesnt love stickers lol highly recommend guitar beginners playing sound quality amazing price get
#
# Content of file67.txt before removing blank spaces:
# looks great sons fender acustic easy put
#
# Content of file717.txt before removing blank spaces:
# ...

# %% [markdown]
# Q2. Unigram Inverted Index and Boolean Queries [40 Marks]
# 1. Create a unigram inverted index (from scratch; No library allowed) of the dataset
# obtained from Q1 (after preprocessing).
# 2. Use Python’s pickle module to save and load the unigram inverted index.
# 3. Provide support for the following operations:
# a. T1 AND T2
# b. T1 OR T2
# c. T1 AND NOT T2
# d. T1 OR NOT T2
# 4. Queries should be generalized i.e., you should provide support for queries like T1 AND
# T2 OR T3 AND T4 ....
# 5. Input format:
# a. The first line contains N denoting the number of queries to execute
# b. The next 2N lines contain queries in the following format:
# i. Input sequence
# ii. Operations separated by comma
#
# 6. Output Format:
# a. 3N lines consisting of the results in the following format:
# i. Query X
# ii. Number of documents retrieved for query X
# iii. Name of the documents retrieved for query X ( as file1.txt )
# 7. Perform preprocessing steps (from Q1) on the input sequence as well.
# 8. Sample Test Case: [Please note that the output values are dummy values; The test case is
# given just to comprehend the format.]
# a. Input:
# 2
# Car bag in a canister
# OR, AND NOT
# Coffee brewing techniques in cookbook
# AND, OR NOT, OR
# b. Output:
# Query 1: car OR bag AND NOT canister
# Number of documents retrieved for query 1: 3
# Names of the documents retrieved for query 1: a.txt, b.txt, c.txt
# Query 2: coffee AND brewing OR NOT techniques OR cookbook
# Number of documents retrieved for query 2: 2
# Names of the documents retrieved for query 2: d.txt, e.txt
#
# 9. You must run your code during the demo and strictly follow the Input/Output format.

# %%
import pickle
from collections import defaultdict

def build_inverted_index(folder_path):
    inverted_index = defaultdict(set)
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.txt'):
            with open(os.path.join(folder_path, file_name), 'r') as file:
                content = file.read()
                tokens = content.split()
                for token in tokens:
                    inverted_index[token].add(file_name)
    return inverted_index

def process_boolean_queries(query, inverted_index):
    query_tokens = query.split()
    results = None
    for token in query_tokens:
        if results is None:
            results = inverted_index.get(token, set())
        else:
            if token == "AND" or token=="and":
                continue
            elif token == "OR" or token=="or":
                continue
            elif token.startswith("NOT"):
                results = results.difference(inverted_index.get(token[3:], set()))
            else:
                results = results.intersection(inverted_index.get(token, set()))
    return results

folder_path = '/content/drive/MyDrive/IR_A1-copy'
inverted_index = build_inverted_index(folder_path)

num_queries = int(input("Enter the number of queries: "))
queries = []
for _ in range(num_queries):
    query = input("Enter your boolean query: ")
    queries.append(query)

for idx, query in enumerate(queries):
    results = process_boolean_queries(query, inverted_index)
    print(f"Query {idx + 1}: {query}")
    print("Number of documents retrieved:", len(results))
    print("Documents retrieved:", results)
# Out:
# Enter the number of queries: 2
# Enter your boolean query: pedal and power
# Enter your boolean query: pedal or power or price
# Query 1: pedal and power
# Number of documents retrieved: 15
# Documents retrieved: {'file828.txt', 'file55.txt', 'file945.txt', 'file760.txt', 'file860.txt', 'file367.txt', 'file703.txt', 'file941.txt', 'file223.txt', 'file47.txt', 'file521.txt', 'file988.txt', 'file305.txt', 'file19.txt', 'file865.txt'}
# Query 2: pedal or power or price
# Number of documents retrieved: 3
# Documents retrieved: {'file860.txt', 'file521.txt', 'file945.txt'}

# %% [markdown]
# Q3. Positional Index and Phrase Queries [40 Marks]
#
# 1. Create a positional index (from scratch; No library allowed) of the dataset obtained from
# Q1.
# 2. Use Python’s pickle module to save and load the positional index.
# 3. Input Format:
# a. The first line contains N denoting the number of queries to execute
# b. The next N lines contain phrase queries
# 4. Output Format:
# a. 2N lines consisting of the results in the following format:
# i. Number of documents retrieved for query X using positional index
# ii. Names of documents retrieved for query X using positional index
# 5. Perform preprocessing steps (from Q1) on the input sequence as well. Assume the
# length of the input sequence to be <=5.
# 6. Sample Test Case: [Please note that the output values are dummy values; The test case
# is given just to comprehend the format.]
# a. Input
# 2
# Car bag in a canister
# Coffee brewing techniques in cookbook
#
# b. Output
# Number of documents retrieved for query 1 using positional index:
# Names of documents retrieved for query 1 using positional index: a.txt, b.txt
# Number of documents retrieved for query 2 using positional index: 2
# Names of documents retrieved for query 2 using positional index: a.txt, b.txt
# 7. You must run your code during the demo and strictly follow the Input/Output format.

# %%
def build_positional_index(folder_path):
    positional_index = defaultdict(dict)
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.txt'):
            with open(os.path.join(folder_path, file_name), 'r', encoding='utf-8') as file:
                content = file.read()
                tokens = content.split()
                for position, token in enumerate(tokens):
                    if token not in positional_index:
                        positional_index[token][file_name] = [position]
                    else:
                        if file_name not in positional_index[token]:
                            positional_index[token][file_name] = [position]
                        else:
                            positional_index[token][file_name].append(position)
    return positional_index

def process_phrase_queries(query, positional_index):
    query_tokens = query.split()
    results = None
    for token in query_tokens:
        if results is None:
            results = positional_index.get(token, {})
        else:
            new_results = {}
            for document, positions in positional_index.get(token, {}).items():
                if document in results:
                    new_positions = []
                    for position in positions:
                        for prev_position in results[document]:
                            if position - prev_position == 1:
                                new_positions.append(position)
                    if new_positions:
                        new_results[document] = new_positions
            results = new_results
    return results

folder_path = '/content/drive/MyDrive/IR_A1-copy'
positional_index = build_positional_index(folder_path)

num_queries = int(input("Enter the number of queries: "))
queries = []
for _ in range(num_queries):
    query = input("Enter your phrase query: ")
    queries.append(query)

for idx, query in enumerate(queries):
    results = process_phrase_queries(query, positional_index)
    print(f"Query {idx + 1}: {query}")
    print("Number of documents retrieved:", len(results))
    print("Documents retrieved:", results)
# Out:
# Enter the number of queries: 2
# Enter your phrase query: much needed
# Enter your phrase query: would need
# Query 1: much needed
# Number of documents retrieved: 1
# Documents retrieved: {'file665.txt': [1]}
# Query 2: would need
# Number of documents retrieved: 0
# Documents retrieved: {}
